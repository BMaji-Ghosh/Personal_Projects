# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Titanic-Dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df=df.drop(['PassengerId','Name','Ticket'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     204 non-null    object
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
df=df.drop('Cabin',axis=1)

# %%
df['Age']=df['Age'].fillna(round(df['Age'].mean()))

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode())
#another approach=df['Embarked'].fillna('S')

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  30.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
#feature encoding
#convert texual data into numerical columns
#one -not encoding

df=pd.get_dummies(data=df,columns=['Sex','Embarked'],dtype=int,drop_first=True)

# %%
x=df.drop('Survived',axis=1)
y=df['Survived']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x.shape
# Out:
# (891, 8)

# %%
y.shape
# Out:
# (891,)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

lr.fit(x_train,y_train)
# Out:
# c:\Users\sanke\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.coef_
# Out:
# array([[-9.39468510e-01, -3.69122728e-02, -2.72148074e-01,
#         -1.45618430e-01,  1.81297903e-03, -2.47609467e+00,
#          1.09971785e-01, -3.37464306e-01]])

# %%
lr.intercept_
# Out:
# array([4.68384796])

# %%
y_pred_train=lr.predict(x_train)

# %%
y_pred_test=lr.predict(x_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83       437
#            1       0.76      0.68      0.71       275
#
#     accuracy                           0.79       712
#    macro avg       0.78      0.77      0.77       712
# weighted avg       0.79      0.79      0.79       712

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       112
#            1       0.80      0.82      0.81        67
#
#     accuracy                           0.85       179
#    macro avg       0.84      0.85      0.85       179
# weighted avg       0.86      0.85      0.86       179

# %%
x.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_male', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
pclass=float(input('Please enter P class here:'))
age=int(input('Please enter Age here:'))
sibsp=int(input('Please enter Number of Sibling Spouse here:'))
parch=int(input('Please enter Number of Parents Children here:'))
fare=int(input('Please enter Budget here:'))
male=(input('Are you male?'))
if male=='yes':
    male=1
else:
    male=0
embarked_q=(input('Did you embark from Queenstown?'))
if embarked_q=='yes':
    embarked_q=1
else:
    embarked_q=0


embarked_s=(input('Did you embark from Southampton?'))
if embarked_s=='yes':
    embarked_s=1
else:
    embarked_s=0

user_input=np.array([pclass,age,sibsp,parch,fare,male,embarked_q,embarked_s]).reshape(1,-1)
if lr.predict(user_input)==0:
    print('RIP! You will not survive')
else:
    print('Hooray! You will survive')
# Out:
# Hooray! You will survive
# c:\Users\sanke\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
